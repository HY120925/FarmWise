# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/processed/final_training_dataset.csv")

print("✅ Dataset loaded. Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nInfo:")
print(df.info())
print("\nMissing Values:")
print(df.isnull().sum())

print("\nSummary statistics:")
print(df.describe(include="all"))

plt.figure(figsize=(12,6))
sns.countplot(y=df['crop'], order=df['crop'].value_counts().index)
plt.title("Crop Distribution")
plt.show()

plt.figure(figsize=(8,5))
sns.countplot(x=df['soil_type'])
plt.title("Soil Type Distribution")
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(8,5))
sns.histplot(df['yield_tons'], bins=20, kde=True)
plt.title("Yield Distribution (tons)")
plt.show()

plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="YlGnBu")
plt.title("Correlation Heatmap")
plt.show()

plt.figure(figsize=(12,6))
sns.boxplot(x="region", y="yield_tons", data=df)
plt.title("Yield by Region")
plt.xticks(rotation=45)
plt.show()
# Out:
# ✅ Dataset loaded. Shape: (5166403, 7)
#
# Columns: ['soil_type', 'crop', 'region', 'fertilizer_used', 'yield_tons', 'water_usage', 'irrigation_type']
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5166403 entries, 0 to 5166402
# Data columns (total 7 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   soil_type        object
#  1   crop             object
#  2   region           object
#  3   fertilizer_used  float64
#  4   yield_tons       float64
#  5   water_usage      float64
#  6   irrigation_type  object
# dtypes: float64(3), object(4)
# memory usage: 275.9+ MB
# None
#
# Missing Values:
# soil_type          0
# crop               0
# region             0
# fertilizer_used    0
# yield_tons         0
# water_usage        0
# irrigation_type    0
# dtype: int64
#
# Summary statistics:
#        soil_type     crop   region  fertilizer_used    yield_tons  \
# count    5166403  5166403  5166403     5.166403e+06  5.166403e+06
# ...
